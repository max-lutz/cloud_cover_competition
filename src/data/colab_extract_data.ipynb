# %%
# !pip install pandas_path --quiet

# %%
# !pip install rasterio -q

# %%
import shutil
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas_path import path
from pathlib import Path
from PIL import Image
import rasterio

from random import randrange

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels.zip -d drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels/phds.tif
#   inflating: drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels/phdv.tif
#   inflating: drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels/pheu.tif
#   inflating: drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels/phfl.tif
#   inflating: drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels/phfr.tif
#   inflating: drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels/phfv.tif
#   inflating: drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels/phgh.tif
#   inflating: drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels/phhg.tif
# ...

# %%
# !unzip drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_features.zip -d drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/

# %%
# !ls drive/MyDrive/DATA_SCIENCE/data_google_colab/cloud_cover/raw/train/train_labels| wc -l
# Out:
# 11748
